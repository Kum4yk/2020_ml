# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# conda install ffmpeg

# %%
test_file_path = "../data/motorama-wind_in_her_hair.mp3"
test_filename = "motorama-wind_in_her_hair.mp3"

# %%
y, sr = librosa.load(test_file_path)

# %%
y_db = librosa.amplitude_to_db(D, ref=np.max);

# %%
D = librosa.stft(y)

# %%
plt.figure(dpi=150)

librosa.display.specshow(
    y_db,
    y_axis='log',
    x_axis='time'
)

plt.title(f'Power spectrogram of {test_filename}')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
